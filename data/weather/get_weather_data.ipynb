# %%
from weather_data_helpers import *
import pycountry
import pickle
import pandas as pd
import numpy as np

# %%
country_list = list(pd.read_pickle('../countries/iso_to_capital.pkl').keys())

# %%
final_df = download_weather_data()
final_df
# Out:
#            iso_code  maxtempC  mintempC  tempC  FeelsLikeC  HeatIndexC  \
# date
# 2020-01-01      AFG         3        -1      3          -2           1
# 2020-01-02      AFG        -1        -4     -1          -4          -2
# 2020-01-03      AFG        -1        -6     -1          -5          -4
# 2020-01-04      AFG         4        -3      4          -2           0
# 2020-01-05      AFG         2        -4      2          -3          -2
# ...             ...       ...       ...    ...         ...         ...
# 2021-01-29      ZWE        23        18     23          20          21
# 2021-01-30      ZWE        24        18     24          20          21
# 2021-01-31      ZWE        26        18     26          22          22
# 2021-02-01      ZWE        26        18     26          22          22
# 2021-02-02      ZWE        24        18     24          20          21
#
#             humidity  pressure  uvIndex  totalSnow_cm  sunHour  windspeedKmph  \
# date
# 2020-01-01        46      1026        1           0.1      3.6              9
# 2020-01-02        95      1028        1           4.5      3.6              5
# 2020-01-03        87      1026        1           0.5      7.0              5
# 2020-01-04        42      1023        2           0.0      8.7              6
# 2020-01-05        52      1022        1           1.0      5.3              5
# ...              ...       ...      ...           ...      ...            ...
# 2021-01-29        86      1013        5           0.0      8.1              7
# 2021-01-30        85      1012        5           0.0     11.9              9
# 2021-01-31        81      1010        5           0.0     12.9             12
# 2021-02-01        82      1011        5           0.0     11.9             12
# 2021-02-02        88      1013        5           0.0      8.1             10
#
#             precipMM
# date
# 2020-01-01       0.4
# 2020-01-02       6.5
# 2020-01-03       0.9
# 2020-01-04       0.0
# 2020-01-05       2.1
# ...              ...
# 2021-01-29      45.1
# 2021-01-30      18.7
# 2021-01-31       1.4
# 2021-02-01       7.6
# 2021-02-02      26.4
#
# [75810 rows x 13 columns]

# %%
for c in country_list:
    country = pycountry.countries.get(alpha_2=c)
    if country:
        final_df = pd.concat([final_df, get_weather_country(country)])
        final_df['iso_code'] = np.where(final_df['iso_code'].isna(), country.alpha_3, final_df['iso_code'])
# Out:
# Retrieving weather data for Dhaka
#
#
# Currently retrieving data for Dhaka: from 2021-02-03 to 2021-02-28
# Key not working anymore, changing...
#
#
# Retrieving weather data for Dhaka
#
#
# Currently retrieving data for Dhaka: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.847561
# Currently retrieving data for Dhaka: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.529011
# Currently retrieving data for Dhaka: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:02.046214
#
#
# Retrieving weather data for Brussels
#
#
# Currently retrieving data for Brussels: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.560802
# Currently retrieving data for Brussels: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.290653
# Currently retrieving data for Brussels: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.779544
#
#
# Retrieving weather data for Ouagadougou
#
#
# Currently retrieving data for Ouagadougou: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.548416
# Currently retrieving data for Ouagadougou: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.203958
# Currently retrieving data for Ouagadougou: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.675677
#
#
# Retrieving weather data for Sofia
#
#
# Currently retrieving data for Sofia: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.572408
# Currently retrieving data for Sofia: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.227158
# Currently retrieving data for Sofia: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.764247
#
#
# Retrieving weather data for Sarajevo
#
#
# Currently retrieving data for Sarajevo: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.600156
# Currently retrieving data for Sarajevo: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.321352
# Currently retrieving data for Sarajevo: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.808489
#
#
# Retrieving weather data for Bridgetown
#
#
# Currently retrieving data for Bridgetown: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.573124
# Currently retrieving data for Bridgetown: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.218637
# Currently retrieving data for Bridgetown: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.691177
# No weather entry for Wallis and Futuna
#
#
# Retrieving weather data for Mata_Utu
#
#
# Currently retrieving data for Mata_Utu: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.663401
# Currently retrieving data for Mata_Utu: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.315970
# Currently retrieving data for Mata_Utu: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.958711
# Currently retrieving data for Mata_Utu: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.597236
# Currently retrieving data for Mata_Utu: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.247920
# Currently retrieving data for Mata_Utu: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.855365
# Currently retrieving data for Mata_Utu: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.507603
# Currently retrieving data for Mata_Utu: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.143771
# Currently retrieving data for Mata_Utu: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.761213
# Currently retrieving data for Mata_Utu: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.419426
# Currently retrieving data for Mata_Utu: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.062510
# Currently retrieving data for Mata_Utu: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.987199
# Currently retrieving data for Mata_Utu: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.658471
# Currently retrieving data for Mata_Utu: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.336740
# Currently retrieving data for Mata_Utu: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.967388
# Currently retrieving data for Mata_Utu: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.475883
# No weather entry for Saint Barthélemy
#
#
# Retrieving weather data for Gustavia
#
#
# Currently retrieving data for Gustavia: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.679952
# Currently retrieving data for Gustavia: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.290102
# Currently retrieving data for Gustavia: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.942753
# Currently retrieving data for Gustavia: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.649497
# Currently retrieving data for Gustavia: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.405062
# Currently retrieving data for Gustavia: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.040958
# Currently retrieving data for Gustavia: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.691940
# Currently retrieving data for Gustavia: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.664809
# Currently retrieving data for Gustavia: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.299062
# Currently retrieving data for Gustavia: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.954381
# Currently retrieving data for Gustavia: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.619605
# Currently retrieving data for Gustavia: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.469421
# Currently retrieving data for Gustavia: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.145279
# Currently retrieving data for Gustavia: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.733387
# Currently retrieving data for Gustavia: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.386445
# Currently retrieving data for Gustavia: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.853732
# No weather entry for Bermuda
#
#
# Retrieving weather data for Hamilton
#
#
# Currently retrieving data for Hamilton: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.672508
# Currently retrieving data for Hamilton: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.303364
# Currently retrieving data for Hamilton: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.970690
# Currently retrieving data for Hamilton: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.616189
# Currently retrieving data for Hamilton: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.296441
# Currently retrieving data for Hamilton: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.986008
# Currently retrieving data for Hamilton: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.633515
# Currently retrieving data for Hamilton: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.305780
# Currently retrieving data for Hamilton: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.931186
# Currently retrieving data for Hamilton: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.555679
# Currently retrieving data for Hamilton: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.186125
# Currently retrieving data for Hamilton: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.845709
# Currently retrieving data for Hamilton: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.607402
# Currently retrieving data for Hamilton: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.224934
# Currently retrieving data for Hamilton: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.874074
# Currently retrieving data for Hamilton: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.450218
#
#
# Retrieving weather data for Bandar_Seri_Begawan
#
#
# Currently retrieving data for Bandar_Seri_Begawan: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.542841
# Currently retrieving data for Bandar_Seri_Begawan: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.247106
# Currently retrieving data for Bandar_Seri_Begawan: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.731682
#
#
# Retrieving weather data for Sucre
#
#
# Currently retrieving data for Sucre: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.572609
# Currently retrieving data for Sucre: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.327952
# Currently retrieving data for Sucre: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.831169
#
#
# Retrieving weather data for Manama
#
#
# Currently retrieving data for Manama: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.531271
# Currently retrieving data for Manama: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.421669
# Currently retrieving data for Manama: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.899883
#
#
# Retrieving weather data for Bujumbura
#
#
# Currently retrieving data for Bujumbura: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.728638
# Currently retrieving data for Bujumbura: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.391146
# Currently retrieving data for Bujumbura: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.887002
#
#
# Retrieving weather data for Porto-Novo
#
#
# Currently retrieving data for Porto-Novo: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.623452
# Currently retrieving data for Porto-Novo: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.506913
# Currently retrieving data for Porto-Novo: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:02.036554
#
#
# Retrieving weather data for Thimphu
#
#
# Currently retrieving data for Thimphu: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.646923
# Currently retrieving data for Thimphu: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.324595
# Currently retrieving data for Thimphu: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.801770
#
#
# Retrieving weather data for Kingston
#
#
# Currently retrieving data for Kingston: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.605651
# Currently retrieving data for Kingston: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.280933
# Currently retrieving data for Kingston: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.772346
# No weather entry for Bouvet Island
#
#
# Retrieving weather data for Gaborone
#
#
# Currently retrieving data for Gaborone: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.673601
# Currently retrieving data for Gaborone: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.342625
# Currently retrieving data for Gaborone: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.897570
#
#
# Retrieving weather data for Apia
#
#
# Currently retrieving data for Apia: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.614192
# Currently retrieving data for Apia: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.259070
# Currently retrieving data for Apia: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.749003
# No weather entry for Bonaire, Sint Eustatius and Saba
#
#
# Retrieving weather data for Brasilia
#
#
# Currently retrieving data for Brasilia: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:01.141894
# Currently retrieving data for Brasilia: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.933097
# Currently retrieving data for Brasilia: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:02.612530
#
#
# Retrieving weather data for Nassau
#
#
# Currently retrieving data for Nassau: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.585125
# Currently retrieving data for Nassau: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.355365
# Currently retrieving data for Nassau: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.879200
# No weather entry for Jersey
#
#
# Retrieving weather data for Saint_Helier
#
#
# Currently retrieving data for Saint_Helier: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.737524
# Currently retrieving data for Saint_Helier: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.476944
# Currently retrieving data for Saint_Helier: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.172542
# Currently retrieving data for Saint_Helier: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.960053
# Currently retrieving data for Saint_Helier: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.635270
# Currently retrieving data for Saint_Helier: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.257936
# Currently retrieving data for Saint_Helier: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.986556
# Currently retrieving data for Saint_Helier: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.665769
# Currently retrieving data for Saint_Helier: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.323346
# Currently retrieving data for Saint_Helier: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.982271
# Currently retrieving data for Saint_Helier: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.463375
# Currently retrieving data for Saint_Helier: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.151466
# Currently retrieving data for Saint_Helier: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.811249
# Currently retrieving data for Saint_Helier: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:11.417179
# Currently retrieving data for Saint_Helier: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.305873
# Currently retrieving data for Saint_Helier: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:12.782137
#
#
# Retrieving weather data for Minsk
#
#
# Currently retrieving data for Minsk: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.590725
# Currently retrieving data for Minsk: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.296765
# Currently retrieving data for Minsk: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.805392
#
#
# Retrieving weather data for Belmopan
#
#
# Currently retrieving data for Belmopan: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.576441
# Currently retrieving data for Belmopan: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.219823
# Currently retrieving data for Belmopan: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.749587
#
#
# Retrieving weather data for Moscow
#
#
# Currently retrieving data for Moscow: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.639836
# Currently retrieving data for Moscow: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.288894
# Currently retrieving data for Moscow: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.747139
#
#
# Retrieving weather data for Kigali
#
#
# Currently retrieving data for Kigali: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.589974
# Currently retrieving data for Kigali: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.353182
# Currently retrieving data for Kigali: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.849938
#
#
# Retrieving weather data for Belgrade
#
#
# Currently retrieving data for Belgrade: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.551197
# Currently retrieving data for Belgrade: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.319663
# Currently retrieving data for Belgrade: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.811877
#
#
# Retrieving weather data for Dili
#
#
# Currently retrieving data for Dili: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.579396
# Currently retrieving data for Dili: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.217499
# Currently retrieving data for Dili: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.714389
# No weather entry for Réunion
#
#
# Retrieving weather data for Saint-Denis
#
#
# Currently retrieving data for Saint-Denis: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.677091
# Currently retrieving data for Saint-Denis: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.296028
# Currently retrieving data for Saint-Denis: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.937276
# Currently retrieving data for Saint-Denis: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.558450
# Currently retrieving data for Saint-Denis: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.221699
# Currently retrieving data for Saint-Denis: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.886346
# Currently retrieving data for Saint-Denis: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.696298
# Currently retrieving data for Saint-Denis: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.479101
# Currently retrieving data for Saint-Denis: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.105989
# Currently retrieving data for Saint-Denis: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.755541
# Currently retrieving data for Saint-Denis: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.391475
# Currently retrieving data for Saint-Denis: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.034813
# Currently retrieving data for Saint-Denis: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.668080
# Currently retrieving data for Saint-Denis: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.274990
# Currently retrieving data for Saint-Denis: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.940953
# Currently retrieving data for Saint-Denis: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.394027
# No weather entry for Turkmenistan
#
#
# Retrieving weather data for Ashgabat
#
#
# Currently retrieving data for Ashgabat: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.746531
# Currently retrieving data for Ashgabat: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.366342
# Currently retrieving data for Ashgabat: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.029972
# Currently retrieving data for Ashgabat: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.671213
# Currently retrieving data for Ashgabat: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.339851
# Currently retrieving data for Ashgabat: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.992746
# Currently retrieving data for Ashgabat: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.648192
# Currently retrieving data for Ashgabat: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.305419
# Currently retrieving data for Ashgabat: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.957931
# Currently retrieving data for Ashgabat: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.638604
# Currently retrieving data for Ashgabat: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.311024
# Currently retrieving data for Ashgabat: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.969097
# Currently retrieving data for Ashgabat: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.621983
# Currently retrieving data for Ashgabat: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.241180
# Currently retrieving data for Ashgabat: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.895371
# Currently retrieving data for Ashgabat: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.534338
#
#
# Retrieving weather data for Dushanbe
#
#
# Currently retrieving data for Dushanbe: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.619286
# Currently retrieving data for Dushanbe: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.275367
# Currently retrieving data for Dushanbe: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.852479
#
#
# Retrieving weather data for Bucharest
#
#
# Currently retrieving data for Bucharest: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.563154
# Currently retrieving data for Bucharest: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.344080
# Currently retrieving data for Bucharest: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:02.030938
# No weather entry for Tokelau
#
#
# Retrieving weather data for Bissau
#
#
# Currently retrieving data for Bissau: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.571241
# Currently retrieving data for Bissau: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.287773
# Currently retrieving data for Bissau: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.794284
# No weather entry for Guam
#
#
# Retrieving weather data for Hagatna
#
#
# Currently retrieving data for Hagatna: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.664009
# Currently retrieving data for Hagatna: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.282882
# Currently retrieving data for Hagatna: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.043967
# Currently retrieving data for Hagatna: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.680457
# Currently retrieving data for Hagatna: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.360431
# Currently retrieving data for Hagatna: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.135071
# Currently retrieving data for Hagatna: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.756026
# Currently retrieving data for Hagatna: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.395889
# Currently retrieving data for Hagatna: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.051917
# Currently retrieving data for Hagatna: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.776408
# Currently retrieving data for Hagatna: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.423262
# Currently retrieving data for Hagatna: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.208455
# Currently retrieving data for Hagatna: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.851112
# Currently retrieving data for Hagatna: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.573263
# Currently retrieving data for Hagatna: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.257292
# Currently retrieving data for Hagatna: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.868967
#
#
# Retrieving weather data for Guatemala_City
#
#
# Currently retrieving data for Guatemala_City: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.565782
# Currently retrieving data for Guatemala_City: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.391992
# Currently retrieving data for Guatemala_City: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.909571
# No weather entry for South Georgia and the South Sandwich Islands
#
#
# Retrieving weather data for Grytviken
#
#
# Currently retrieving data for Grytviken: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.708664
# Currently retrieving data for Grytviken: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.297496
# Currently retrieving data for Grytviken: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.994955
# Currently retrieving data for Grytviken: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.652025
# Currently retrieving data for Grytviken: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.301434
# Currently retrieving data for Grytviken: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.968432
# Currently retrieving data for Grytviken: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.608265
# Currently retrieving data for Grytviken: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.272354
# Currently retrieving data for Grytviken: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.898247
# Currently retrieving data for Grytviken: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.569143
# Currently retrieving data for Grytviken: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.235029
# Currently retrieving data for Grytviken: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.897770
# Currently retrieving data for Grytviken: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.641400
# Currently retrieving data for Grytviken: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.261091
# Currently retrieving data for Grytviken: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.880288
# Currently retrieving data for Grytviken: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.340322
#
#
# Retrieving weather data for Athens
#
#
# Currently retrieving data for Athens: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.587804
# Currently retrieving data for Athens: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.222430
# Currently retrieving data for Athens: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.687557
#
#
# Retrieving weather data for Malabo
#
#
# Currently retrieving data for Malabo: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.654685
# Currently retrieving data for Malabo: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.290385
# Currently retrieving data for Malabo: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.768677
# No weather entry for Guadeloupe
#
#
# Retrieving weather data for Basse-Terre
#
#
# Currently retrieving data for Basse-Terre: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.681520
# Currently retrieving data for Basse-Terre: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.314916
# Currently retrieving data for Basse-Terre: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.965215
# Currently retrieving data for Basse-Terre: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.613774
# Currently retrieving data for Basse-Terre: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.271245
# Currently retrieving data for Basse-Terre: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.944509
# Currently retrieving data for Basse-Terre: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.627251
# Currently retrieving data for Basse-Terre: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.292075
# Currently retrieving data for Basse-Terre: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.929848
# Currently retrieving data for Basse-Terre: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.580882
# Currently retrieving data for Basse-Terre: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.277125
# Currently retrieving data for Basse-Terre: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.943433
# Currently retrieving data for Basse-Terre: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.600042
# Currently retrieving data for Basse-Terre: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.249535
# Currently retrieving data for Basse-Terre: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.936144
# Currently retrieving data for Basse-Terre: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.417950
#
#
# Retrieving weather data for Tokyo
#
#
# Currently retrieving data for Tokyo: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.586735
# Currently retrieving data for Tokyo: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.228188
# Currently retrieving data for Tokyo: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.707423
#
#
# Retrieving weather data for Georgetown
#
#
# Currently retrieving data for Georgetown: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.577711
# Currently retrieving data for Georgetown: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.235862
# Currently retrieving data for Georgetown: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.947386
# No weather entry for Guernsey
#
#
# Retrieving weather data for St_Peter_Port
#
#
# Currently retrieving data for St_Peter_Port: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.653661
# Currently retrieving data for St_Peter_Port: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.258447
# Currently retrieving data for St_Peter_Port: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.872397
# Currently retrieving data for St_Peter_Port: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.497206
# Currently retrieving data for St_Peter_Port: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.197996
# Currently retrieving data for St_Peter_Port: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.852587
# Currently retrieving data for St_Peter_Port: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.509289
# Currently retrieving data for St_Peter_Port: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.184220
# Currently retrieving data for St_Peter_Port: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.814359
# Currently retrieving data for St_Peter_Port: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.456648
# Currently retrieving data for St_Peter_Port: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.086494
# Currently retrieving data for St_Peter_Port: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.836882
# Currently retrieving data for St_Peter_Port: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.775456
# Currently retrieving data for St_Peter_Port: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.374774
# Currently retrieving data for St_Peter_Port: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.013574
# Currently retrieving data for St_Peter_Port: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.523397
# No weather entry for French Guiana
#
#
# Retrieving weather data for Cayenne
#
#
# Currently retrieving data for Cayenne: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.704956
# Currently retrieving data for Cayenne: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.317526
# Currently retrieving data for Cayenne: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.016434
# Currently retrieving data for Cayenne: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.795798
# Currently retrieving data for Cayenne: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.447431
# Currently retrieving data for Cayenne: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.231953
# Currently retrieving data for Cayenne: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.096057
# Currently retrieving data for Cayenne: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.729516
# Currently retrieving data for Cayenne: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.370687
# Currently retrieving data for Cayenne: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.021673
# Currently retrieving data for Cayenne: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.651757
# Currently retrieving data for Cayenne: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.307012
# Currently retrieving data for Cayenne: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.103916
# Currently retrieving data for Cayenne: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.709784
# Currently retrieving data for Cayenne: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.350623
# Currently retrieving data for Cayenne: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.984876
#
#
# Retrieving weather data for Tbilisi
#
#
# Currently retrieving data for Tbilisi: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.573125
# Currently retrieving data for Tbilisi: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.237088
# Currently retrieving data for Tbilisi: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.709075
#
#
# Retrieving weather data for St._George's
#
#
# Currently retrieving data for St._George's: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.580591
# Currently retrieving data for St._George's: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.232555
# Currently retrieving data for St._George's: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.722057
#
#
# Retrieving weather data for London
#
#
# Currently retrieving data for London: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.591439
# Currently retrieving data for London: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.237010
# Currently retrieving data for London: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.729780
#
#
# Retrieving weather data for Libreville
#
#
# Currently retrieving data for Libreville: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.566286
# Currently retrieving data for Libreville: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.202356
# Currently retrieving data for Libreville: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.680398
#
#
# Retrieving weather data for San_Salvador
#
#
# Currently retrieving data for San_Salvador: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.567036
# Currently retrieving data for San_Salvador: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.298290
# Currently retrieving data for San_Salvador: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.794989
#
#
# Retrieving weather data for Conakry
#
#
# Currently retrieving data for Conakry: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.563484
# Currently retrieving data for Conakry: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.211322
# Currently retrieving data for Conakry: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.777945
#
#
# Retrieving weather data for Banjul
#
#
# Currently retrieving data for Banjul: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.590204
# Currently retrieving data for Banjul: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.221018
# Currently retrieving data for Banjul: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.685838
# No weather entry for Greenland
#
#
# Retrieving weather data for Nuuk
#
#
# Currently retrieving data for Nuuk: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.688803
# Currently retrieving data for Nuuk: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.331201
# Currently retrieving data for Nuuk: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.995239
# Currently retrieving data for Nuuk: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.648445
# Currently retrieving data for Nuuk: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.354795
# Currently retrieving data for Nuuk: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.976755
# Currently retrieving data for Nuuk: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.746918
# Currently retrieving data for Nuuk: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.529776
# Currently retrieving data for Nuuk: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.163558
# Currently retrieving data for Nuuk: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.881683
# Currently retrieving data for Nuuk: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.513318
# Currently retrieving data for Nuuk: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.163371
# Currently retrieving data for Nuuk: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.830450
# Currently retrieving data for Nuuk: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.524902
# Currently retrieving data for Nuuk: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.169653
# Currently retrieving data for Nuuk: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.637337
# No weather entry for Gibraltar
#
#
# Retrieving weather data for Gibraltar
#
#
# Currently retrieving data for Gibraltar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.611420
# Currently retrieving data for Gibraltar: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.188363
# Currently retrieving data for Gibraltar: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.852443
# Currently retrieving data for Gibraltar: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.473797
# Currently retrieving data for Gibraltar: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.105622
# Currently retrieving data for Gibraltar: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.832990
# Currently retrieving data for Gibraltar: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.474543
# Currently retrieving data for Gibraltar: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.101487
# Currently retrieving data for Gibraltar: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.727310
# Currently retrieving data for Gibraltar: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.344568
# Currently retrieving data for Gibraltar: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.949301
# Currently retrieving data for Gibraltar: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.577190
# Currently retrieving data for Gibraltar: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.217912
# Currently retrieving data for Gibraltar: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:08.800382
# Currently retrieving data for Gibraltar: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.550797
# Currently retrieving data for Gibraltar: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.007127
#
#
# Retrieving weather data for Accra
#
#
# Currently retrieving data for Accra: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.557381
# Currently retrieving data for Accra: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.194709
# Currently retrieving data for Accra: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.656577
#
#
# Retrieving weather data for Muscat
#
#
# Currently retrieving data for Muscat: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.734599
# Currently retrieving data for Muscat: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.424625
# Currently retrieving data for Muscat: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.906937
#
#
# Retrieving weather data for Tunis
#
#
# Currently retrieving data for Tunis: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.546383
# Currently retrieving data for Tunis: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.177694
# Currently retrieving data for Tunis: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.715823
#
#
# Retrieving weather data for Amman
#
#
# Currently retrieving data for Amman: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.588781
# Currently retrieving data for Amman: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.213999
# Currently retrieving data for Amman: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.682777
#
#
# Retrieving weather data for Zagreb
#
#
# Currently retrieving data for Zagreb: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.577188
# Currently retrieving data for Zagreb: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.197761
# Currently retrieving data for Zagreb: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.679132
#
#
# Retrieving weather data for Port-au-Prince
#
#
# Currently retrieving data for Port-au-Prince: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.552816
# Currently retrieving data for Port-au-Prince: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.196537
# Currently retrieving data for Port-au-Prince: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.710707
#
#
# Retrieving weather data for Budapest
#
#
# Currently retrieving data for Budapest: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.581600
# Currently retrieving data for Budapest: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.198954
# Currently retrieving data for Budapest: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.668000
#
#
# Retrieving weather data for Hong_Kong
#
#
# Currently retrieving data for Hong_Kong: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.541340
# Currently retrieving data for Hong_Kong: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.163424
# Currently retrieving data for Hong_Kong: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.619102
#
#
# Retrieving weather data for Tegucigalpa
#
#
# Currently retrieving data for Tegucigalpa: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.583876
# Currently retrieving data for Tegucigalpa: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.267290
# Currently retrieving data for Tegucigalpa: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.854781
# No weather entry for Heard Island and McDonald Islands
#
#
# Retrieving weather data for Caracas
#
#
# Currently retrieving data for Caracas: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.600628
# Currently retrieving data for Caracas: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.256501
# Currently retrieving data for Caracas: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.736038
# No weather entry for Puerto Rico
#
#
# Retrieving weather data for San_Juan
#
#
# Currently retrieving data for San_Juan: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.714425
# Currently retrieving data for San_Juan: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.335770
# Currently retrieving data for San_Juan: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.125159
# Currently retrieving data for San_Juan: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.751853
# Currently retrieving data for San_Juan: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.467284
# Currently retrieving data for San_Juan: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.130318
# Currently retrieving data for San_Juan: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.920941
# Currently retrieving data for San_Juan: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.580279
# Currently retrieving data for San_Juan: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.219854
# Currently retrieving data for San_Juan: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.847065
# Currently retrieving data for San_Juan: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.506345
# Currently retrieving data for San_Juan: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.306850
# Currently retrieving data for San_Juan: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.103918
# Currently retrieving data for San_Juan: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.793495
# Currently retrieving data for San_Juan: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.484116
# Currently retrieving data for San_Juan: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.947826
#
#
# Retrieving weather data for East_Jerusalem
#
#
# Currently retrieving data for East_Jerusalem: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.562106
# Currently retrieving data for East_Jerusalem: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.269226
# Currently retrieving data for East_Jerusalem: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.722071
# No weather entry for Palau
#
#
# Retrieving weather data for Melekeok
#
#
# Currently retrieving data for Melekeok: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.661787
# Currently retrieving data for Melekeok: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.447511
# Currently retrieving data for Melekeok: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.095797
# Currently retrieving data for Melekeok: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.710583
# Currently retrieving data for Melekeok: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.373356
# Currently retrieving data for Melekeok: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.003663
# Currently retrieving data for Melekeok: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.647851
# Currently retrieving data for Melekeok: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.307268
# Currently retrieving data for Melekeok: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.951677
# Currently retrieving data for Melekeok: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.740467
# Currently retrieving data for Melekeok: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.372940
# Currently retrieving data for Melekeok: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.016443
# Currently retrieving data for Melekeok: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.666536
# Currently retrieving data for Melekeok: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.270116
# Currently retrieving data for Melekeok: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.899016
# Currently retrieving data for Melekeok: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.501718
#
#
# Retrieving weather data for Lisbon
#
#
# Currently retrieving data for Lisbon: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.554855
# Currently retrieving data for Lisbon: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.220970
# Currently retrieving data for Lisbon: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.718101
# No weather entry for Svalbard and Jan Mayen
#
#
# Retrieving weather data for Longyearbyen
#
#
# Currently retrieving data for Longyearbyen: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.634516
# Currently retrieving data for Longyearbyen: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.243696
# Currently retrieving data for Longyearbyen: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.906781
# Currently retrieving data for Longyearbyen: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.539696
# Currently retrieving data for Longyearbyen: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.242036
# ...
# Time elapsed (hh:mm:ss.ms) 0:00:01.792769
#
#
# Retrieving weather data for St._John's
#
#
# Currently retrieving data for St._John's: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.569793
# Currently retrieving data for St._John's: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.325585
# Currently retrieving data for St._John's: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.789811
#
#
# Retrieving weather data for Kabul
#
#
# Currently retrieving data for Kabul: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.567716
# Currently retrieving data for Kabul: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.233714
# Currently retrieving data for Kabul: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.713511
# No weather entry for Anguilla
#
#
# Retrieving weather data for The_Valley
#
#
# Currently retrieving data for The_Valley: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.691632
# Currently retrieving data for The_Valley: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.306811
# Currently retrieving data for The_Valley: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.606240
# Currently retrieving data for The_Valley: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.410210
# Currently retrieving data for The_Valley: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.076449
# Currently retrieving data for The_Valley: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.800132
# Currently retrieving data for The_Valley: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.520669
# Currently retrieving data for The_Valley: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.273222
# Currently retrieving data for The_Valley: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.956072
# Currently retrieving data for The_Valley: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.680251
# Currently retrieving data for The_Valley: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.295015
# Currently retrieving data for The_Valley: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.981057
# Currently retrieving data for The_Valley: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.705086
# Currently retrieving data for The_Valley: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:10.343294
# Currently retrieving data for The_Valley: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.117724
# Currently retrieving data for The_Valley: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:11.633415
# No weather entry for Virgin Islands, U.S.
#
#
# Retrieving weather data for Charlotte_Amalie
#
#
# Currently retrieving data for Charlotte_Amalie: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.630020
# Currently retrieving data for Charlotte_Amalie: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.318132
# Currently retrieving data for Charlotte_Amalie: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.080359
# Currently retrieving data for Charlotte_Amalie: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.750707
# Currently retrieving data for Charlotte_Amalie: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.377845
# Currently retrieving data for Charlotte_Amalie: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.077060
# Currently retrieving data for Charlotte_Amalie: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.755727
# Currently retrieving data for Charlotte_Amalie: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.411310
# Currently retrieving data for Charlotte_Amalie: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.043076
# Currently retrieving data for Charlotte_Amalie: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.681185
# Currently retrieving data for Charlotte_Amalie: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.348184
# Currently retrieving data for Charlotte_Amalie: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.031234
# Currently retrieving data for Charlotte_Amalie: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.694621
# Currently retrieving data for Charlotte_Amalie: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:10.385893
# Currently retrieving data for Charlotte_Amalie: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.516232
# Currently retrieving data for Charlotte_Amalie: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:12.998538
#
#
# Retrieving weather data for Reykjavik
#
#
# Currently retrieving data for Reykjavik: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.585274
# Currently retrieving data for Reykjavik: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.440505
# Currently retrieving data for Reykjavik: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:02.022888
#
#
# Retrieving weather data for Tehran
#
#
# Currently retrieving data for Tehran: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.683159
# Currently retrieving data for Tehran: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.410249
# Currently retrieving data for Tehran: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:02.066517
#
#
# Retrieving weather data for Yerevan
#
#
# Currently retrieving data for Yerevan: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.642612
# Currently retrieving data for Yerevan: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.292510
# Currently retrieving data for Yerevan: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.756632
#
#
# Retrieving weather data for Tirana
#
#
# Currently retrieving data for Tirana: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.666492
# Currently retrieving data for Tirana: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.374106
# Currently retrieving data for Tirana: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.934248
#
#
# Retrieving weather data for Luanda
#
#
# Currently retrieving data for Luanda: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.565899
# Currently retrieving data for Luanda: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.262794
# Currently retrieving data for Luanda: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.728083
# No weather entry for Antarctica
# No weather entry for American Samoa
#
#
# Retrieving weather data for Pago_Pago
#
#
# Currently retrieving data for Pago_Pago: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.733641
# Currently retrieving data for Pago_Pago: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.456076
# Currently retrieving data for Pago_Pago: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.114108
# Currently retrieving data for Pago_Pago: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.762953
# Currently retrieving data for Pago_Pago: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.451128
# Currently retrieving data for Pago_Pago: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.096670
# Currently retrieving data for Pago_Pago: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.716748
# Currently retrieving data for Pago_Pago: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.381986
# Currently retrieving data for Pago_Pago: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.993964
# Currently retrieving data for Pago_Pago: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.646084
# Currently retrieving data for Pago_Pago: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.481066
# Currently retrieving data for Pago_Pago: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.191847
# Currently retrieving data for Pago_Pago: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.855195
# Currently retrieving data for Pago_Pago: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.474591
# Currently retrieving data for Pago_Pago: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.152206
# Currently retrieving data for Pago_Pago: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.640823
#
#
# Retrieving weather data for Buenos_Aires
#
#
# Currently retrieving data for Buenos_Aires: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.561733
# Currently retrieving data for Buenos_Aires: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.228838
# Currently retrieving data for Buenos_Aires: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.718647
#
#
# Retrieving weather data for Canberra
#
#
# Currently retrieving data for Canberra: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.606155
# Currently retrieving data for Canberra: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.253038
# Currently retrieving data for Canberra: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.898937
#
#
# Retrieving weather data for Vienna
#
#
# Currently retrieving data for Vienna: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.601068
# Currently retrieving data for Vienna: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.232222
# Currently retrieving data for Vienna: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.699253
# No weather entry for Aruba
#
#
# Retrieving weather data for Oranjestad
#
#
# Currently retrieving data for Oranjestad: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.679765
# Currently retrieving data for Oranjestad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.298477
# Currently retrieving data for Oranjestad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.978990
# Currently retrieving data for Oranjestad: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.598785
# Currently retrieving data for Oranjestad: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.256786
# Currently retrieving data for Oranjestad: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.930116
# Currently retrieving data for Oranjestad: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.572173
# Currently retrieving data for Oranjestad: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.259304
# Currently retrieving data for Oranjestad: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.896780
# Currently retrieving data for Oranjestad: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.891591
# Currently retrieving data for Oranjestad: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.535966
# Currently retrieving data for Oranjestad: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.233822
# Currently retrieving data for Oranjestad: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.998783
# Currently retrieving data for Oranjestad: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.611546
# Currently retrieving data for Oranjestad: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.245632
# Currently retrieving data for Oranjestad: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:10.723482
#
#
# Retrieving weather data for New_Delhi
#
#
# Currently retrieving data for New_Delhi: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.648546
# Currently retrieving data for New_Delhi: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.288757
# Currently retrieving data for New_Delhi: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.813931
# No weather entry for Åland Islands
#
#
# Retrieving weather data for Mariehamn
#
#
# Currently retrieving data for Mariehamn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.640661
# Currently retrieving data for Mariehamn: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:01.237666
# Currently retrieving data for Mariehamn: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.917224
# Currently retrieving data for Mariehamn: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.586686
# Currently retrieving data for Mariehamn: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.292930
# Currently retrieving data for Mariehamn: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.960478
# Currently retrieving data for Mariehamn: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.711123
# Currently retrieving data for Mariehamn: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.491717
# Currently retrieving data for Mariehamn: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.152504
# Currently retrieving data for Mariehamn: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.820031
# Currently retrieving data for Mariehamn: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.608017
# Currently retrieving data for Mariehamn: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.420683
# Currently retrieving data for Mariehamn: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.266324
# Currently retrieving data for Mariehamn: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:09.909525
# Currently retrieving data for Mariehamn: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.542770
# Currently retrieving data for Mariehamn: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:11.036648
#
#
# Retrieving weather data for Baku
#
#
# Currently retrieving data for Baku: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.582089
# Currently retrieving data for Baku: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.224593
# Currently retrieving data for Baku: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.730701
#
#
# Retrieving weather data for Dublin
#
#
# Currently retrieving data for Dublin: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.652461
# Currently retrieving data for Dublin: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.291504
# Currently retrieving data for Dublin: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.771482
#
#
# Retrieving weather data for Jakarta
#
#
# Currently retrieving data for Jakarta: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.586533
# Currently retrieving data for Jakarta: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.255634
# Currently retrieving data for Jakarta: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.770072
#
#
# Retrieving weather data for Kiev
#
#
# Currently retrieving data for Kiev: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.582806
# Currently retrieving data for Kiev: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.220945
# Currently retrieving data for Kiev: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.823088
#
#
# Retrieving weather data for Doha
#
#
# Currently retrieving data for Doha: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.719909
# Currently retrieving data for Doha: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.382556
# Currently retrieving data for Doha: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.860463
#
#
# Retrieving weather data for Maputo
#
#
# Currently retrieving data for Maputo: from 2021-02-03 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.685981
# Currently retrieving data for Maputo: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.405606
# Currently retrieving data for Maputo: from 2021-04-01 to 2021-04-21
# Time elapsed (hh:mm:ss.ms) 0:00:01.914448

# %%
final_df
# Out:
#            iso_code maxtempC mintempC tempC FeelsLikeC HeatIndexC humidity  \
# date
# 2020-01-01      AFG        3       -1     3         -2          1       46
# 2020-01-02      AFG       -1       -4    -1         -4         -2       95
# 2020-01-03      AFG       -1       -6    -1         -5         -4       87
# 2020-01-04      AFG        4       -3     4         -2          0       42
# 2020-01-05      AFG        2       -4     2         -3         -2       52
# ...             ...      ...      ...   ...        ...        ...      ...
# 2021-04-17      MOZ       23       18    23         20         21       59
# 2021-04-18      MOZ       25       16    25         21         21       65
# 2021-04-19      MOZ       27       17    27         22         22       68
# 2021-04-20      MOZ       25       19    25         23         23       72
# 2021-04-21      MOZ       28       18    28         24         24       70
#
#            pressure uvIndex totalSnow_cm sunHour windspeedKmph precipMM
# date
# 2020-01-01     1026       1          0.1     3.6             9      0.4
# 2020-01-02     1028       1          4.5     3.6             5      6.5
# 2020-01-03     1026       1          0.5     7.0             5      0.9
# 2020-01-04     1023       2          0.0     8.7             6      0.0
# 2020-01-05     1022       1          1.0     5.3             5      2.1
# ...             ...     ...          ...     ...           ...      ...
# 2021-04-17     1026       5          0.0     5.7            15      0.5
# 2021-04-18     1024       6          0.0     8.7            10      0.0
# 2021-04-19     1021       6          0.0     8.7            12      0.0
# 2021-04-20     1022       5          0.0     4.2            10      1.9
# 2021-04-21     1021       6          0.0     8.7            10      0.0
#
# [191244 rows x 13 columns]

# %%
final_df.drop_duplicates().to_csv('./weather_data.csv')
